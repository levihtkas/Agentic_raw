# %%
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("../resume.pdf")
user_resume = ""

for page in reader.pages:
    text = page.extract_text()
    if text:
        user_resume+=text
user_resume
# Out:
# 'Curriculum Vitae \n \nB. VIJAYALAKSHMI \n \nMobile No. : 8838232684 \nE-mail : vijibalakrishnan.lakshmi@gmail.com \n \nC2, Saijeevan Towers, \n36, Ganapathi Street, \nAlagappan Nagar, \nMadurai-625003. \n \n \nProfile \n\uf040 Having 13 years and 8 months of teaching experience in handling UG & PG \nECE courses. \n \n\uf040 Achieved 100% results in various UG & PG subjects. \n \n\uf040 Doing Ph.D. in the in the domain of Image Processing under Anna University. \n \n\uf040 Presented and published research papers in International journals and   in \nInternational & National Conferences. \n \n\uf040 Organized and attended a number of FDPs, Workshops and Seminars. \n \n\uf040 Completed NPTEL Course in Principle of Communication Systems-1 with Elite \nCertificate. \n \n\uf040 Life member in ISTE, IETE. \n \n \n \nEDUCATIONAL QUALIFICATION \nDegree University / Institute Month & \nYear Class \n \nPh.D. in ECE \nAnna University, Chennai \nUnder the guidance of \nDr. B. Yogameena, Associate Professor, \nDepartment of ECE, Thiagarajar College \nof Engineering, Madurai-625015 \n \n \nUnder Progress \nM.E. Applied Electronics Karunya Institute of technology, \nCoimbatore -641114 April – 2005 First \nB.E.(ECE) Thiagarajar college of Engineering, \nMadurai-625015 April - 1998 Second College of Engineering, Madurai. \n \nEXPERIENCE \n \nPositions Held Duration No. of Years \nAssociate Professor in ECE \nAssistant Professor in ECE \nSenior Lecturer in ECE \nLecturer in ECE \nKLN College of Information Technology, Madurai. \n1.7.2010- 30.3.2019  \n9.01.2010-30.06.2010 \n1.7.2009-8.01.2010 \n25.07.2005-30.6.2009 \n \n \n13 Years 8 Months \nLecturer, \nDepartment of Electronics, \nCPA College of Arts and Science \nBodinayakanur-625513 \n24.8.1998-20.4.1999 \n2.7.99-20.4.2000  \n19.6.2000 -31.10.2000  \n \n1 Year 9 Months \n \n \n \nFDP/SEMINAR/WORKSHOP – ATTENDED \n \n \n \n• Attended a one-week AICTE -QIP Sponsored Short Term Course on ‘ Vision Based Robot \nNavigation and Manipulation ’ from 22 nd to 28 th January, 2018 at Thiagarajar College of \nEngineering, Madurai. \n• Attended two weeks AICTE Sponsored Faculty Development Programme on “ Research \nPerspectives on Robotics and Vision ” from 27 th Nov, 2017 to 10 th Dec, 2017 at Thiagarajar \nCollege of Engineering, Madurai. \n• Attended one day International Seminar on "Intellectual Property Rights (IPR)” on 4th Oct, \n2017 at KLN College of Information Technology, Madurai. \n• Attended five days ICMR Sponsored National Level Workshop on ‘ Computer Vision and \nImage Processing for Dental Applications’ from 18th to 22nd September, 2017 at KLN College of \nInformation Technology, Madurai. \n• Attended one day workshop on “Deep Learning” on 29th July, 2017 at Mepco Schlenk College of \nEngineering, Sivakasi \n• Attended two days workshop on “ VLSI Design Laboratory” on 11 th & 12 th January, 2017 at \nKLN College of Engineering, Madurai. \n• Attended two days FDP on “ Internet of Things (IoT) Communications & Networking \nPerspective” on 20th & 21st December, 2016 at KLN College of Information Technology, Madurai. \n• Attended TEQIP-II sponsored one day workshop on “ Research Paper W riting” on 23 rd Dec \n2016 at Thiagarajar College of Engineering, Madurai. \n• Attended two days TEQIP –II sponsored ACM Distinguished Speaker Programme on Image \nProcessing and Computer Vision using MATLAB” on 9th & 10th December, 2016 at Thiagarajar College of Engineering, Madurai. \n \n• Attended two days workshop on “ Trends and Developments on Optical and Microwave \nCommunications” on 14th & 15th September, 2016 at K.L.N. College of Information Technology, \nMadurai. \n• Attended two days hands on training workshop on “Xilinx Vivado Design Flow & High-Level \nSynthesis Flow Using Zynq ” on 11 th & 12 th, February,2016 at KLN College of Engineering, \nMadurai. \n• Attended two days workshop on “ Image Processing and Pattern Recognition -Research” on \n20th & 21st March, 2015 at Thiagarajar College of En ...

# %%
name="Vijayalakshmi B"
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## {user_resume}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

def chat(message,history):
    print(f"\n\n {history} \n")
    messages = [{"role":"system","content":system_prompt}]+history+[{"role":"user","content":message}]
    response = openai.chat.completions.create(model="gpt-4o-mini",messages=messages)
    return response.choices[0].message.content

gr.ChatInterface(chat,type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#  history
