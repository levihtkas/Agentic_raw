# %%
from dotenv import load_dotenv
from agents import Agent,Runner,trace

load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="Jokester",instructions="suggest AI enchancements and devs",model="gpt-4o-mini") # Initializing the instances

with trace('Suggeestor'): # adding trace for visiblity and tracking
    result = await Runner.run(agent,'Tell me a good agentic project') # Run the agent and provide the command
    print(result.final_output) # final result
# Out:
# A great agentic project that you could consider is **“Community-Based Health App”**. Here’s a breakdown of the project:
#
# ### Project Overview:
# Develop a mobile application that empowers individuals to manage their health proactively while fostering community engagement. The app could include features for tracking health metrics, sharing wellness tips, and connecting with local health resources.
#
# ### Key Features:
#
# 1. **Personal Health Dashboard**:
#    - Users can track their physical activities, diet, sleep patterns, and mental health.
#
# 2. **Community Support Forums**:
#    - A space for users to share experiences, ask questions, and support each other.
#
# 3. **Local Health Resource Finder**:
#    - Users can find nearby healthcare providers, wellness workshops, and support groups.
#
# 4. **Customizable Health Goals**:
#    - Users set and track personal health goals with reminders and motivation through the app.
#
# 5. **Educational Content**:
# ...
